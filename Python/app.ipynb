# %%
from spectral import *

# %%
img = open_image('wrap_resize_flaash.hdr').load()
v=imshow(img)
print(img.__class__)
# Out:
# <class 'spectral.image.ImageArray'>

# %%
(m, c) = kmeans(img, 5, 30)
# Out:
# spectral:INFO: k-means iteration 1 - 64339 pixels reassigned.
# spectral:INFO: k-means iteration 2 - 12362 pixels reassigned.
# spectral:INFO: k-means iteration 3 - 2981 pixels reassigned.
# spectral:INFO: k-means iteration 4 - 2669 pixels reassigned.
# spectral:INFO: k-means iteration 5 - 3073 pixels reassigned.
# spectral:INFO: k-means iteration 6 - 2910 pixels reassigned.
# spectral:INFO: k-means iteration 7 - 2725 pixels reassigned.
# spectral:INFO: k-means iteration 8 - 2471 pixels reassigned.
# spectral:INFO: k-means iteration 9 - 2072 pixels reassigned.
# spectral:INFO: k-means iteration 10 - 1819 pixels reassigned.
# spectral:INFO: k-means iteration 11 - 1544 pixels reassigned.
# spectral:INFO: k-means iteration 12 - 1364 pixels reassigned.
# spectral:INFO: k-means iteration 13 - 1203 pixels reassigned.
# spectral:INFO: k-means iteration 14 - 985 pixels reassigned.
# spectral:INFO: k-means iteration 15 - 864 pixels reassigned.
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
for i in range(c.shape[0]):
    plt.plot(c[i])
plt.grid()

# %%
v=imshow(classes=m)
